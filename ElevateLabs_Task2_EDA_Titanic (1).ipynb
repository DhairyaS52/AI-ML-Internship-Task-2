# %% [markdown]
# # Exploratory Data Analysis (EDA) - Titanic Dataset
#
# ## AI & ML Internship - Task 2
#
# ### Objective
# To understand and analyze the Titanic dataset using descriptive statistics and data visualization techniques.
#
# ### Tools Used
# - Python
# - Pandas
# - NumPy
# - Matplotlib
# - Seaborn

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")
pd.set_option("display.max_columns", None)

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %% [markdown]
# ## 2. Load Dataset
#
# Upload `titanic.csv` to Google Colab before running the next cell.

# %%
df = pd.read_csv("Titanic-Dataset.csv")

print("Dataset loaded successfully!")
# Out:
# Dataset loaded successfully!

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## 3. Basic Dataset Inspection

# %%
print("Dataset Shape:", df.shape)
print("\nColumn Names:")
print(df.columns.tolist())
# Out:
# Dataset Shape: (891, 12)
#
# Column Names:
# ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ## 4. Summary Statistics

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                 Name   Sex  \
# count    891.000000  891.000000  891.000000                  891   891
# unique          NaN         NaN         NaN                  891     2
# top             NaN         NaN         NaN  Dooley, Mr. Patrick  male
# freq            NaN         NaN         NaN                    1   577
# mean     446.000000    0.383838    2.308642                  NaN   NaN
# std      257.353842    0.486592    0.836071                  NaN   NaN
# min        1.000000    0.000000    1.000000                  NaN   NaN
# 25%      223.500000    0.000000    2.000000                  NaN   NaN
# 50%      446.000000    0.000000    3.000000                  NaN   NaN
# 75%      668.500000    1.000000    3.000000                  NaN   NaN
# max      891.000000    1.000000    3.000000                  NaN   NaN
#
#                Age       SibSp       Parch  Ticket        Fare Cabin Embarked
# ...

# %%
print("Median Values:")
print(df.median(numeric_only=True))
# Out:
# Median Values:
# PassengerId    446.0000
# Survived         0.0000
# Pclass           3.0000
# Age             28.0000
# SibSp            0.0000
# Parch            0.0000
# Fare            14.4542
# dtype: float64

# %%
print("Standard Deviation:")
print(df.std(numeric_only=True))
# Out:
# Standard Deviation:
# PassengerId    257.353842
# Survived         0.486592
# Pclass           0.836071
# Age             14.526497
# SibSp            1.102743
# Parch            0.806057
# Fare            49.693429
# dtype: float64

# %% [markdown]
# ## 5. Missing Values and Duplicate Rows

# %%
print("Missing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
print("Number of Duplicate Rows:", df.duplicated().sum())
# Out:
# Number of Duplicate Rows: 0

# %% [markdown]
# ## 6. Data Cleaning for EDA

# %%
df["Age"] = df["Age"].fillna(df["Age"].median())
df["Embarked"] = df["Embarked"].fillna(df["Embarked"].mode()[0])

print("Missing values after cleaning:")
print(df.isnull().sum())
# Out:
# Missing values after cleaning:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %% [markdown]
# ## 7. Categorical Feature Analysis
#
# The following visualizations help understand the distribution of important categorical features.

# %%
fig, axes = plt.subplots(1, 3, figsize=(16, 5))

sns.countplot(data=df, x="Sex", ax=axes[0])
axes[0].set_title("Passenger Distribution by Sex")

sns.countplot(data=df, x="Pclass", ax=axes[1])
axes[1].set_title("Passenger Distribution by Class")

sns.countplot(data=df, x="Embarked", ax=axes[2])
axes[2].set_title("Passenger Distribution by Port of Embarkation")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 8. Histograms of Numeric Features

# %%
numeric_features = ["Age", "Fare", "SibSp", "Parch"]

df[numeric_features].hist(
    figsize=(12, 8),
    bins=20,
    edgecolor="black"
)

plt.suptitle("Histograms of Numeric Features", fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 9. Age Distribution

# %%
plt.figure(figsize=(8, 5))

sns.histplot(data=df, x="Age", bins=30, kde=True)

plt.title("Age Distribution of Passengers")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ## 10. Fare Distribution

# %%
plt.figure(figsize=(8, 5))

sns.histplot(data=df, x="Fare", bins=30, kde=True)

plt.title("Fare Distribution")
plt.xlabel("Fare")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ## 11. Boxplots for Numeric Features

# %%
plt.figure(figsize=(12, 6))

sns.boxplot(data=df[numeric_features])

plt.title("Boxplots of Numeric Features")
plt.xlabel("Features")
plt.ylabel("Values")
plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(data=df, y="Fare")

plt.title("Boxplot of Fare")
plt.ylabel("Fare")
plt.show()

# %% [markdown]
# ## 12. Survival Distribution

# %%
plt.figure(figsize=(6, 4))

sns.countplot(data=df, x="Survived")

plt.title("Distribution of Survival")
plt.xlabel("Survived (0 = No, 1 = Yes)")
plt.ylabel("Number of Passengers")
plt.show()

# %%
survival_rate = df["Survived"].mean() * 100
print(f"Overall Survival Rate: {survival_rate:.2f}%")
# Out:
# Overall Survival Rate: 38.38%

# %% [markdown]
# ## 13. Survival by Gender

# %%
plt.figure(figsize=(7, 5))

sns.countplot(data=df, x="Sex", hue="Survived")

plt.title("Survival Count by Gender")
plt.xlabel("Gender")
plt.ylabel("Number of Passengers")
plt.show()

# %%
print("Survival Rate by Gender:")
print((df.groupby("Sex")["Survived"].mean() * 100).round(2))
# Out:
# Survival Rate by Gender:
# Sex
# female    74.20
# male      18.89
# Name: Survived, dtype: float64

# %% [markdown]
# ## 14. Survival by Passenger Class

# %%
plt.figure(figsize=(7, 5))

sns.countplot(data=df, x="Pclass", hue="Survived")

plt.title("Survival Count by Passenger Class")
plt.xlabel("Passenger Class")
plt.ylabel("Number of Passengers")
plt.show()

# %%
print("Survival Rate by Passenger Class:")
print((df.groupby("Pclass")["Survived"].mean() * 100).round(2))
# Out:
# Survival Rate by Passenger Class:
# Pclass
# 1    62.96
# 2    47.28
# 3    24.24
# Name: Survived, dtype: float64

# %% [markdown]
# ## 15. Age vs Survival

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(data=df, x="Survived", y="Age")

plt.title("Age Distribution by Survival")
plt.xlabel("Survived (0 = No, 1 = Yes)")
plt.ylabel("Age")
plt.show()

# %% [markdown]
# ## 16. Fare vs Passenger Class

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(data=df, x="Pclass", y="Fare")

plt.title("Fare Distribution by Passenger Class")
plt.xlabel("Passenger Class")
plt.ylabel("Fare")
plt.show()

# %% [markdown]
# ## 17. Pairplot

# %%
pairplot_columns = ["Survived", "Pclass", "Age", "SibSp", "Parch", "Fare"]

sns.pairplot(
    df[pairplot_columns],
    hue="Survived",
    diag_kind="hist"
)

plt.show()

# %% [markdown]
# ## 18. Correlation Matrix

# %%
numeric_df = df.select_dtypes(include=np.number)
correlation_matrix = numeric_df.corr()

correlation_matrix
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.034212 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.064910 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.339898  0.083081  0.018443
# Age             0.034212 -0.064910 -0.339898  1.000000 -0.233296 -0.172482
# SibSp          -0.057527 -0.035322  0.083081 -0.233296  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.172482  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096688  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096688
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %% [markdown]
# ## 19. Correlation Heatmap

# %%
plt.figure(figsize=(10, 8))

sns.heatmap(
    correlation_matrix,
    annot=True,
    cmap="coolwarm",
    fmt=".2f",
    linewidths=0.5
)

plt.title("Correlation Matrix Heatmap")
plt.show()

# %% [markdown]
# ## 20. Skewness Analysis

# %%
skewness = df[numeric_features].skew()

print("Skewness of Numeric Features:")
print(skewness)
# Out:
# Skewness of Numeric Features:
# Age      0.510245
# Fare     4.787317
# SibSp    3.695352
# Parch    2.749117
# dtype: float64

# %% [markdown]
# ### Interpretation of Skewness
#
# - Skewness close to 0 indicates an approximately symmetric distribution.
# - Positive skewness indicates a right-skewed distribution.
# - Negative skewness indicates a left-skewed distribution.

# %% [markdown]
# ## 21. Outlier Detection Using IQR

# %%
def detect_outliers_iqr(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = data[
        (data[column] < lower_bound) |
        (data[column] > upper_bound)
    ]

    return len(outliers), lower_bound, upper_bound


for column in numeric_features:
    count, lower, upper = detect_outliers_iqr(df, column)

    print(f"\n{column}")
    print(f"Outliers: {count}")
    print(f"Lower Bound: {lower:.2f}")
    print(f"Upper Bound: {upper:.2f}")
# Out:
# Age
# Outliers: 66
# Lower Bound: 2.50
# Upper Bound: 54.50
#
# Fare
# Outliers: 116
# Lower Bound: -26.72
# Upper Bound: 65.63
#
# SibSp
# Outliers: 46
# Lower Bound: -1.50
# Upper Bound: 2.50
#
# Parch
# Outliers: 213
# Lower Bound: 0.00
# Upper Bound: 0.00

# %% [markdown]
# ## 22. Conclusion
#
# Exploratory Data Analysis was performed on the Titanic dataset using Pandas, Matplotlib, and Seaborn. Descriptive statistics and visualizations were used to understand the structure and distribution of the data.
#
# Histograms and boxplots helped identify skewness and potential outliers, while pairplots and correlation analysis helped understand relationships between numerical features. The analysis also revealed that factors such as gender and passenger class were strongly associated with survival.
#
# This EDA process provided important insights into the dataset and highlighted data quality issues that should be addressed before applying machine learning models.
